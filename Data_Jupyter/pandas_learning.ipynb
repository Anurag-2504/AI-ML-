# %%
import pandas as pd

# %%
roll_no = pd.Series(["Anshul","Ritik","Anurag","Adil"], index=[20,18,21,27])

print(roll_no)

print(roll_no[21])
# Out:
# 20    Anshul
# 18     Ritik
# 21    Anurag
# 27      Adil
# dtype: object
# Anurag
